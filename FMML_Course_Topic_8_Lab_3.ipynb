# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasadattili/FMML-22B21A4440/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-26-4996ee3d8d09> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     135     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-01 15:23:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   282MB/s    in 0.2s
#
# 2024-04-01 15:23:09 (282 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35834   1301.2281v2  In this work, we introduce graphical modelsfor...    cs
# 26603  1611.04782v1  This study concerns the effectiveness of sever...    cs
# 39442  1603.09725v2  Speaker diarization consists of assigning spee...    cs
# 28505  1706.08917v3  Across a majority of pedestrian detection data...    cs
# 35995   0903.1139v1  Constraint propagation is one of the technique...    cs
# ...             ...                                                ...   ...
# 22890  1710.01931v1  Understanding player behavior is fundamental i...  stat
# 2124   1511.06890v1  This paper presents a novel nonmyopic adaptive...  stat
# 1590   1505.00277v1  We present an approach for the detection of co...    cs
# 1111   1710.09574v1  In this study, we propose a novel deep neural ...  stat
# 22374  1605.00388v2  Separating the short jobs from the long is a k...  stat
#
#                                                    title  year  \
# 35834                   Graphical Models for Game Theory  2013
# 26603  Feature Extraction and Soft Computing Methods ...  2016
# 39442  Audio-Visual Speaker Diarization Based on Spat...  2016
# 28505  Rotational Rectification Network: Enabling Ped...  2017
# 35995  The Complexity of Reasoning with Global Constr...  2009
# ...                                                  ...   ...
# 22890  Forecasting Player Behavioral Data and Simulat...  2017
# 2124   Gaussian Process Planning with Lipschitz Conti...  2015
# 1590   Grounded Discovery of Coordinate Term Relation...  2015
# 1111   Biologically Inspired Feedforward Supervised L...  2017
# 22374  Highly Accurate Prediction of Jobs Runtime Cla...  2016
#
#                                                 keywords
# 35834  [introduce, graphical, modelsfor, algorithms, ...
# 26603  [effectiveness, techniques, processing, interp...
# 39442  [diarization, assigning, spatiotemporal, diari...
# 28505  [pedestrian, detection, typically, pedestrians...
# 35995  [constraint, propagation, techniques, constrai...
# ...                                                  ...
# 22890  [understanding, fundamental, experience, succe...
# 2124   [nonmyopic, framework, lipschitz, continuous, ...
# 1590   [detection, coordinate, relationships, relatio...
# 1111   [supervised, feedforward, supervisory, associa...
# 22374  [separating, technique, scheduling, performanc...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35834    [introduce, graphical, modelsfor, algorithms, ...
# 26603    [effectiveness, techniques, processing, interp...
# 39442    [diarization, assigning, spatiotemporal, diari...
# 28505    [pedestrian, detection, typically, pedestrians...
# 35995    [constraint, propagation, techniques, constrai...
#                                ...
# 31326    [introduce, character, recognition, commercial...
# 21870    [unsupervised, unlabelled, definition, charact...
# 39113    [important, operation, processing, corresponde...
# 254      [increasingly, recognition, supporting, collec...
# 12790    [manipulation, deformable, important, challeng...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8917 words.
# Out of those 4584 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="393ebe81-f5e9-4593-a39a-412146308bcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("393ebe81-f5e9-4593-a39a-412146308bcb")) {                    Plotly.newPlot(                        "393ebe81-f5e9-4593-a39a-412146308bcb",                        [{"x":["solutions","interpretation","underlying","complexity","desirable","computation","exponential","representation","equilibria","interacting","distributed","efficient","algorithm","determined","potential","introduce","inference","undirected","directions","computing","technical","maximizing","properties","propagation","neighbors","graphical","algorithms","implemented","polynomial","approximate","approximation","partially","involving","themselves","extensions","illustrate","structures","correlation","experimental","extraction","successful","effectiveness","experiments","competitors","application","resulting","performance","different","retrieval","classification","destructive","processing","detection","classifier","outperforms","diagnosis","performed","including","techniques","sensitivity","precision","implementation","structure","specificity","evaluated","principled","spatiotemporal","microphone","benchmarked","formulation","challenging","diarization","procedure","clustering","association","thoroughly","simultaneously","advantage","scenarios","following","alignment","interaction","identities","assigning","localization","extracted","processes","participants","technique","introduced","supervised","platforms","detectors","situations","construction","rectification","rotational","significant","typically","pedestrian","information","transformer","estimation","pedestrians","coordinate","convolutional","assumption","constraint","determine","computational","characterise","combining","questions","decomposing","quadratic","intractable","particular","tractability","generalized","tractable","consistency","associated","therefore","reasoning","constraints","variables","demonstrate","programming","intractability","important","dependencies","highlight","shortcomings","extracting","components","interactions","incorporating","extensive","relevance","intuitively","component","combination","ingredients","disambiguation","successfully","conducted","established","capturing","comparisons","considering","shuffling","surrounding","contribute","statistically","appropriate","similarity","computationally","selection","functional","expensive","statistics","constructs","influences","posterior","distributions","generative","likelihood","simulated","crucially","predefined","impossible","distribution","difficult","framework","performing","approaches","regression","relationship","artificial","preserving","consistent","explanation","combinatorial","exhaustive","conceptual","impractical","manageable","enumeration","functionality","potentially","explanatory","observation","decomposition","explaining","sequential","intelligence","relations","represent","explanations","technologies"],"y":[154,65,118,221,37,152,48,366,5,17,107,410,798,40,160,330,224,12,37,134,40,37,205,74,24,67,605,111,59,125,112,46,47,18,37,71,134,78,366,122,67,206,565,8,248,164,908,755,105,506,3,288,352,171,237,45,117,242,363,34,78,139,360,15,123,31,19,2,6,85,242,2,115,122,24,12,109,82,96,76,34,88,9,15,64,117,114,20,254,118,188,30,35,37,72,3,2,250,121,13,684,12,211,7,33,379,85,101,80,262,7,121,72,11,35,17,294,6,77,28,54,105,148,127,142,149,535,112,5,350,56,32,18,54,107,73,55,160,29,14,105,120,1,14,93,96,46,49,34,62,3,16,23,21,76,154,82,173,45,60,81,18,9,50,127,104,78,61,10,15,20,209,146,514,91,407,125,81,137,50,66,24,37,11,18,10,4,7,15,38,3,60,59,12,75,107,81,119,17,36],"type":"bar"},{"x":["solutions","interpretation","underlying","complexity", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4584,), (4584, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style=''>of</span> <span style=''>DNA</span> <span style=''>Binding</span> <span style=''>Proteins</span> <span style=''>Using</span> <span style=''>Machine</span> <span style=''>Learning</span> <br/><br/><span style=''>DNA</span> <span style=''>binding</span> <span style=''>proteins</span> <span style=''>are</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>proteins</span> <span style=''>which</span> <span style=''>have</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>or</span> <span style=''>general</span> <span style=''>affinity</span> <span style=''>to</span> <span style=''>DNA</span> <span style=''>and</span> <span style=''>include</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transcription</span> <span style=''>factors</span> <span style=''>nucleases</span> <span style=''>and</span> <span style=''>histones</span> <span style=''>DNA</span> <span style=''>binding</span> <span style=''>proteins</span> <span style=''>also</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>roles</span> <span style=''>in</span> <span style=''>many</span> <span style=''>types</span> <span style=''>of</span> <span style=''>cellular</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>activities</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>systems</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style=''>DNA</span> <span style=''>binding</span> <span style=''>proteins</span> <span style=''>where</span> <span style=''>a</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>and</span> <span style=''>a</span> <span style=''>Cascade</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlation</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimized</span> <span style=''>and</span> <span style=''>then</span> <span style=''>compared</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determine</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>achieves</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3078393881453156);'>information</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.4893617021276597);'>characteristics</span> <span style=''>that</span> <span style=''>include</span> <span style=''>overall</span> <span style=''>charge</span> <span style=''>patch</span> <span style=''>size</span> <span style=''>and</span> <span style=''>amino</span> <span style=''>acids</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>composition</span> <span style=''>In</span> <span style=''>total</span> <span style=''>121</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Implicit</span> <span style=''>Causal</span> <span style=''>Models</span> <span style=''>for</span> <span style=''>Genome</span> <span style=''>wide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Association</span> <span style=''>Studies</span> <br/><br/><span style=''>Progress</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developing</span> <span style=''>richer</span> <span style=''>models</span> <span style=''>with</span> <span style=''>neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>implicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>densities</span> <span style=''>and</span> <span style=''>with</span> <span style=''>scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>their</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>However</span> <span style=''>there</span> <span style=''>has</span> <span style=''>been</span> <span style=''>limited</span> <span style=''>progress</span> <span style=''>in</span> <span style=''>models</span> <span style=''>that</span> <span style=''>capture</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>for</span> <span style=''>example</span> <span style=''>how</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>genetic</span> <span style=''>factors</span> <span style=''>cause</span> <span style=''>major</span> <span style=''>human</span> <span style=''>diseases</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>How</span> <span style=''>do</span> <span style=''>we</span> <span style=''>build</span> <span style=''>richer</span> <span style=''>causal</span> <span style=''>models</span> <span style=''>which</span> <span style=''>can</span> <span style=''>capture</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>between</span> <span style=''>multiple</span> <span style=''>causes</span> <span style=''>How</span> <span style=''>do</span> <span style=''>we</span> <span style=''>adjust</span> <span style=''>for</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounders</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influencing</span> <span style=''>both</span> <span style=''>cause</span> <span style=''>and</span> <span style=''>effect</span> <span style=''>and</span> <span style=''>which</span> <span style=''>prevent</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>To</span> <span style=''>address</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synth ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>About</span> <span style=''>one</span> <span style=''>3</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>Model</span> <span style=''>of</span> <span style=''>Testing</span> <br/><br/><span style=''>This</span> <span style=''>article</span> <span style=''>offers</span> <span style=''>a</span> <span style=''>3</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>model</span> <span style=''>of</span> <span style=''>testing</span> <span style=''>with</span> <span style=''>1)</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difference</span> <span style=''>between</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>level</span> <span style=''>of</span> <span style=''>the</span> <span style=''>examinee</span> <span style=''>and</span> <span style=''>item</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulty</span> <span style=''>2)</span> <span style=''>the</span> <span style=''>examinee</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrimination</span> <span style=''>and</span> <span style=''>3)</span> <span style=''>the</span> <span style=''>item</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrimination</span> <span style=''>as</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reproducibility</span> <span style=''>and</span> <span style=''>high</span> <span style=''>accuracy</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style=''>topic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <br/><br/><span style=''>Much</span> <span style=''>of</span> <span style=''>human</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>sits</span> <span style=''>in</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unstructured</span> <span style=''>text</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Leveraging</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>requires</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>extract</span> <span style=''>and</span> <span style=''>record</span> <span style=''>metadata</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unstructured</span> <span style=''>text</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>documents</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Assigning</span> <span style=''>topics</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>documents</span> <span style=''>will</span> <span style=''>enable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intelligent</span> <span style=''>search</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterization</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>meaningful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocation</span> <span style=''>(LDA)</span> <span style=''>is</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>in</span> <span style=''>topic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>perform</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>systematic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style=''>analysis</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrates</span> <span style=''>that</span> <span style=''>current</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>for</span> <span style=''>LDA</span> <span style=''>often</span> <span style=''>yield</span> <span style=''>results</span> <span style=''>which</span> <span style=''>are</span> <span style=''>not</span> <span style=''>accurate</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style=''>the</span> <span style=''>most</span> <span style=''>suitable</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>Adapting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style='background-color:rg ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09499820079165168)
# 	representation (0.1317020510975171)
# 	architecture (0.08888089240734078)
# 	segmentation (0.06980928391507736)
# 	knowledge (0.12378553436487945)
# 	information (0.24613170205109752)
# 	detection (0.12666426772220224)
# 	different (0.2716804605973372)
# 	recognition (0.13422094278517452)
# 	convolutional (0.1363799928031666)
#
# Some Statistics words are:
# 	convergence (0.11924789708065314)
# 	statistical (0.15437902028698663)
# 	stochastic (0.140524492825334)
# 	algorithm (0.38050470064324593)
# 	estimation (0.16971796140524492)
# 	theoretical (0.15091538842157348)
# 	distribution (0.17911924789708064)
# 	inference (0.19594260267194458)
# 	dimensional (0.1904997525977239)
# 	regression (0.17120237506185057)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5c0add3c-a626-4df2-a2b3-01600627c05f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c0add3c-a626-4df2-a2b3-01600627c05f")) {                    Plotly.newPlot(                        "5c0add3c-a626-4df2-a2b3-01600627c05f",                        [{"x":["solutions","interpretation","underlying","complexity","desirable","computation","exponential","representation","equilibria","interacting","distributed","efficient","algorithm","determined","potential","introduce","inference","undirected","directions","computing","technical","maximizing","properties","propagation","neighbors","graphical","algorithms","implemented","polynomial","approximate","approximation","partially","involving","themselves","extensions","illustrate","structures","correlation","experimental","extraction","successful","effectiveness","experiments","competitors","application","resulting","performance","different","retrieval","classification","destructive","processing","detection","classifier","outperforms","diagnosis","performed","including","techniques","sensitivity","precision","implementation","structure","specificity","evaluated","principled","spatiotemporal","microphone","benchmarked","formulation","challenging","diarization","procedure","clustering","association","thoroughly","simultaneously","advantage","scenarios","following","alignment","interaction","identities","assigning","localization","extracted","processes","participants","technique","introduced","supervised","platforms","detectors","situations","construction","rectification","rotational","significant","typically","pedestrian","information","transformer","estimation","pedestrians","coordinate","convolutional","assumption","constraint","determine","computational","characterise","combining","questions","decomposing","quadratic","intractable","particular","tractability","generalized","tractable","consistency","associated","therefore","reasoning","constraints","variables","demonstrate","programming","intractability","important","dependencies","highlight","shortcomings","extracting","components","interactions","incorporating","extensive","relevance","intuitively","component","combination","ingredients","disambiguation","successfully","conducted","established","capturing","comparisons","considering","shuffling","surrounding","contribute","statistically","appropriate","similarity","computationally","selection","functional","expensive","statistics","constructs","influences","posterior","distributions","generative","likelihood","simulated","crucially","predefined","impossible","distribution","difficult","framework","performing","approaches","regression","relationship","artificial","preserving","consistent","explanation","combinatorial","exhaustive","conceptual","impractical","manageable","enumeration","functionality","potentially","explanatory","observation","decomposition","explaining","sequential","intelligence","relations","represent","explanations","technologies","sometimes","improvements","aggregation","adaptation","theoretical","respectively","prediction","electricity","specialist","arbitrary","sequences","forecasting","contributions","aggregating","predictions","consumption","specialized","methodology","occasional","literature","concerned","empirical","parameters","nonparametric","available","efficiency","dimension","filtering","advantages","conditional","applications","synthetic","tensorflow","partitioning","recursively","benchmarks","comparison","probability","smoothing","hierarchical","dependence","successive","incrementally","abnormality","conventional","considers","behaviour","consideration","dirichlet","observations","wikipedia","vocabulary","probabilistic","pipelines","mapreduce","u ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	multipartite
# 	reassignment
# 	confronted
# 	semiparametric
# 	contamination
# 	integrand
# 	blockwise
# 	competitiveness
# 	regulating
# 	mcallester
# 	exponents
# 	staleness
# 	accommodating
# 	subpopulations
# 	customization
# 	supermodular
# 	distinguishability
# 	unweighted
# 	covariates
# 	trainability
# Some words which never appear in Statistics papers:
# 	equilibria
# 	destructive
# 	rectification
# 	transformer
# 	implementable
# 	princeton
# 	sentential
# 	delivering
# 	devastating
# 	traversed
# 	designers
# 	interfering
# 	transformational
# 	physicists
# 	something
# 	sensorimotor
# 	alternatively
# 	ventricle
# 	ventricular
# 	anticipation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0888984987953295e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
